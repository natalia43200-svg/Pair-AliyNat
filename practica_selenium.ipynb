# %%
from selenium import webdriver  # Selenium es una herramienta para automatizar la interacción con navegadores web.
from webdriver_manager.chrome import ChromeDriverManager  # ChromeDriverManager gestiona la instalación del controlador de Chrome.
from selenium.webdriver.common.keys import Keys  # Keys es útil para simular eventos de teclado en Selenium.
from selenium.webdriver.support.ui import Select  # Select se utiliza para interactuar con elementos <select> en páginas web.
# Importar librerías para pausar la ejecución
# -----------------------------------------------------------------------
from time import sleep

# %%
url = "https://www.casadellibro.com/"

# %%
driver = webdriver.Chrome()

driver.get(url)

sleep(3)

# 3. Maximizamos la pantalla
driver.maximize_window()
sleep(5)

driver.find_element("css selector", "#onetrust-accept-btn-handler").click()
sleep(5)

driver.find_element("css selector", "#App > div.cma-components.container.d-grid.svelte-f3gp65 > cma-component:nth-child(1) > div.hero.svelte-1u46vbz > div > a").click()
sleep(5)

driver.find_element("css selector", "#App > div.cma-components.container.d-grid.svelte-f3gp65 > cma-component:nth-child(2) > div > div.d-grid.gap-4.items.full-width.svelte-1g07cxu > div:nth-child(5) > a > p").click()
sleep(5)

driver.find_element("css selector", "#App > div.cma-components.container.d-grid.svelte-f3gp65 > cma-component:nth-child(1) > div > area-4 > label").click()
sleep(2)

# %%
#App > div.cma-components.container.d-grid.svelte-f3gp65 > cma-component:nth-child(1) > div > area-4 > label
